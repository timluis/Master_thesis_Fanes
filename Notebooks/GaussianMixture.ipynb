# %% [markdown]
# # Gaussian Mixture from Lavarella Spring

# %%
cd ..
# Out:
# c:\Users\timph\OneDrive - uibk.ac.at\GitHub\Master_thesis_Fanes

# %%
import DownloadDatabase as dd 
import Plots as plts 
import Processing as pc

# %%
df = plts.LoadLavarellaQuelleExcel(rule="Hourly")

# %%
gmm_mean,gmm_weight, gmm_covari=plts.ConductivityGaussMixture(data=df.loc['2019-04-14':'2020-01-20'],components=3,gmm_kwargs={"n_init":10})

# %%
gmm_mean,gmm_weight, gmm_covari=plts.ConductivityGaussMixture(data=df.loc['2018-04-10':'2018-12-30'],components=2,gmm_kwargs={"n_init":10})
