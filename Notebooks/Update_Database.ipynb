# %% [markdown]
# # Notebook to download new data and update the database

# %%
cd ..
# Out:
# c:\Users\timph\OneDrive - uibk.ac.at\GitHub\Master_thesis_Fanes

# %%
import DownloadDatabase as dd

# %%
dd.UpdateAll()
# Out:
# ...
# The station code is :42830SF
# Looking for the latest date in database...
# The latest date is: 20201103
# Second date is set to present day... 20201210
# Days between your dates : 37
# ...
# Days between your dates : 37
# ...
# Days between your dates : 37
# ...
# Adding data from Rossalm to raw database
# Loading json data from directory
# new file ['WeatherData\\Rossalm\\Rossalm_HS_from_20201103_to_20201210.json', 'WeatherData\\Rossalm\\Rossalm_LF_from_20201103_to_20201210.json', 'WeatherData\\Rossalm\\Rossalm_LT_from_20201103_to_20201210.json']
#
# Reading file Rossalm_HS_from_20201103_to_20201210.json to dataframe...
# Reading file Rossalm_LF_from_20201103_to_20201210.json to dataframe...
# Reading file Rossalm_LT_from_20201103_to_20201210.json to dataframe...
# Rename columns...
# Check for empty dataframes...
# Join all dataframes into one...
# Adding station ID...
# ...
# Checking for existing data
# ...
# In Line (3504920,) existing date found
# In Line None existing date found
# ...
